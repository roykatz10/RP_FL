prox_10c_iid_ed = np.load("log_nc10_nro400_str1_lr0.0001_rho0.5_dsetMNIST_10c_iid1_ed1.npy")
prox_10c_niid_ed = np.load("log_nc10_nro400_str1_lr0.0001_rho0.5_dsetMNIST_10c_iid0_ed1.npy")
prox_10c_iid_ned = None
prox_10c_niid_ned = np.load("log_nc10_nro400_str1_lr0.0001_rho0.5_dsetMNIST_10c_iid0_ed0.npy")

### fedMedian
med_10c_iid_ed = np.load("log_nc10_nro400_str2_lr0.0001_rho0.5_dsetMNIST_10c_iid1_ed1.npy")
med_10c_niid_ed = None
med_10c_iid_ned = np.load("log_nc10_nro400_str2_lr0.0001_rho0.5_dsetMNIST_10c_iid1_ed0.npy")
med_10c_niid_ned = None

### QFedAvg
Q_10c_iid_ed = None
Q_10c_niid_ed = np.load("log_nc10_nro400_str3_lr0.0001_rho0.5_dsetMNIST_10c_iid0_ed1.npy")
Q_10c_iid_ned = np.load("log_nc10_nro400_str3_lr0.0001_rho0.5_dsetMNIST_10c_iid1_ed0.npy")
Q_10c_niid_ned = np.load("log_nc10_nro400_str3_lr0.0001_rho0.5_dsetMNIST_10c_iid0_ed0.npy")


### Yogi
# Yogi_10c_iid_ed = np.load("log_nc10_nro400_str4_lr0.0001_rho0.5_dsetMNIST_10c.npy")
Yogi_10c_iid_ed = None
Yogi_10c_niid_ed = np.load("log_nc10_nro400_str4_lr0.0001_rho0.5_dsetMNIST_10c_iid0_ed1.npy")
Yogi_10c_iid_ned = np.load("log_nc10_nro400_str4_lr0.0001_rho0.5_dsetMNIST_10c_iid1_ed0.npy")
Yogi_10c_niid_ned = np.load("log_nc10_nro400_str4_lr0.0001_rho0.5_dsetMNIST_10c_iid0_ed0.npy")


### ADMM
ADMM_10c_iid_ed = None
ADMM_10c_niid_ed = None
ADMM_10c_iid_ned = None
ADMM_10c_niid_ned = None

# %%
## IID, ed
strats = [central_MNIST, favg_10c_iid_ed, prox_10c_iid_ed, med_10c_iid_ed, Yogi_10c_iid_ed, Q_10c_iid_ed]
strat_names = ['central', 'fedAvg', 'fedProx', 'fedMedian', 'fedYogi', 'QFedAvg']

for i, strat in enumerate(strats):
    plt.plot(strat, label = strat_names[i])

plt.legend()
plt.grid()
plt.title("MNIST 10c, IID, ed")
# Out:
# Text(0.5, 1.0, 'MNIST 10c, IID, ed')

# %%
## nIID, ed
strats = [central_MNIST, favg_10c_niid_ed, prox_10c_niid_ed, med_10c_niid_ed, Yogi_10c_niid_ed, Q_10c_niid_ed]
strat_names = ["central", 'fedAvg', 'fedProx', 'fedMedian', 'fedYogi', 'QFedAvg']

for i, strat in enumerate(strats):
    plt.plot(strat, label = strat_names[i])

plt.legend()
plt.grid()
plt.title("MNIST 10c, nIID, ed")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 6
#       3 strat_names = ["central", 'fedAvg', 'fedProx', 'fedMedian', 'fedYogi', 'QFedAvg']
#       5 for i, strat in enumerate(strats):
# ----> 6     plt.plot(strat, label = strat_names[i])
#       8 plt.legend()
#       9 plt.grid()
#
# File /tudelft.net/staff-bulk/ewi/insy/DBL/swiergarst/envs/flower2en/lib/python3.9/site-packages/matplotlib/pyplot.py:3578, in plot(scalex, scaley, data, *args, **kwargs)
#    3570 @_copy_docstring_and_deprecators(Axes.plot)
#    3571 def plot(
#    3572     *args: float | ArrayLike | str,
#    (...)
#    3576     **kwargs,
#    3577 ) -> list[Line2D]:
# -> 3578     return gca().plot(
#    3579         *args,
#    3580         scalex=scalex,
#    3581         scaley=scaley,
#    3582         **({"data": data} if data is not None else {}),
#    3583         **kwargs,
# ...

# %%
## nIID, ned
strats = [central_MNIST, favg_10c_niid_ned, prox_10c_niid_ned, med_10c_niid_ned, Yogi_10c_niid_ned, Q_10c_niid_ned]
strat_names = ['central', 'fedAvg', 'fedProx', 'fedMedian', 'fedYogi', 'QFedAvg']

for i, strat in enumerate(strats):
    plt.plot(strat, label = strat_names[i])

plt.legend()
plt.grid()
plt.title("MNIST 10c, nIID, ned")
# Out:
# Text(0.5, 1.0, 'MNIST 10c, nIID, ned')

# %%
## IID, ned
strats = [favg_10c_iid_ned, prox_10c_iid_ned, med_10c_iid_ned, Yogi_10c_iid_ned, Q_10c_iid_ned]
strat_names = ['fedAvg', 'fedProx', 'fedMedian', 'fedYogi', 'QFedAvg']

for i, strat in enumerate(strats):
    plt.plot(strat, label = strat_names[i])

plt.legend()
plt.grid()
plt.title("MNIST 10c, IID, ned")
# Out:
# Text(0.5, 1.0, 'MNIST 10c, IID, ned')

# %% [markdown]
# ## MNIST 50 clients

# %%
### favg
favg_50c_iid_ed = np.load("log_nc50_nro400_str0_lr0.0001_rho0.5_dsetMNIST_50c_iid1_ed1.npy")
favg_50c_niid_ed = np.load("log_nc50_nro400_str0_lr0.0001_rho0.5_dsetMNIST_50c_iid0_ed1.npy")
favg_50c_iid_ned = np.load("log_nc50_nro400_str0_lr0.0001_rho0.5_dsetMNIST_50c_iid1_ed0.npy")
favg_50c_niid_ned = None 

### fedProx
prox_50c_iid_ed = np.load("log_nc50_nro400_str1_lr0.0001_rho0.5_dsetMNIST_50c.npy")
prox_50c_niid_ed = np.load("log_nc50_nro400_str1_lr0.0001_rho0.5_dsetMNIST_50c_iidFalse_edTrue.npy")
prox_50c_iid_ned = np.load("log_nc50_nro400_str1_lr0.0001_rho0.5_dsetMNIST_50c_iidTrue_edFalse.npy")
prox_50c_niid_ned = np.load("log_nc50_nro400_str1_lr0.0001_rho0.5_dsetMNIST_50c_iidFalse_edFalse.npy")

### fedMedian
med_50c_iid_ed = np.load("log_nc50_nro400_str2_lr0.0001_rho0.5_dsetMNIST_50c.npy")
med_50c_niid_ed = np.load("log_nc50_nro400_str2_lr0.0001_rho0.5_dsetMNIST_50c_iidFalse_edTrue.npy")
med_50c_iid_ned = np.load("log_nc50_nro400_str2_lr0.0001_rho0.5_dsetMNIST_50c_iidTrue_edFalse.npy")
med_50c_niid_ned = np.load("log_nc50_nro400_str2_lr0.0001_rho0.5_dsetMNIST_50c_iidFalse_edFalse.npy")

### QFedAvg
Q_50c_iid_ed = np.load("log_nc50_nro400_str3_lr0.0001_rho0.5_dsetMNIST_50c.npy")
Q_50c_niid_ed = np.load("log_nc50_nro400_str3_lr0.0001_rho0.5_dsetMNIST_50c_iidFalse_edTrue.npy")
Q_50c_iid_ned = np.load("log_nc50_nro400_str3_lr0.0001_rho0.5_dsetMNIST_50c_iidTrue_edFalse.npy")
Q_50c_niid_ned = np.load("log_nc50_nro400_str3_lr0.0001_rho0.5_dsetMNIST_50c_iidFalse_edFalse.npy")

### Yogi
Yogi_50c_iid_ed = np.load("log_nc50_nro400_str4_lr0.0001_rho0.5_dsetMNIST_50c.npy")
Yogi_50c_niid_ed = np.load("log_nc50_nro400_str4_lr0.0001_rho0.5_dsetMNIST_50c_iidFalse_edTrue.npy")
Yogi_50c_iid_ned = np.load("log_nc50_nro400_str4_lr0.0001_rho0.5_dsetMNIST_50c_iidTrue_edFalse.npy")
Yogi_50c_niid_ned = np.load("log_nc50_nro400_str4_lr0.0001_rho0.5_dsetMNIST_50c_iidFalse_edFalse.npy")

### ADMM
ADMM_50c_iid_ed = None
ADMM_50c_niid_ed = None
ADMM_50c_iid_ned = np.load("log_nc50_nro400_str5_lr0.0001_rho0.5_dsetMNIST_50c_iidTrue_edFalse.npy")
ADMM_50c_niid_ned = None

# %%
## IID, ed
strats = [favg_50c_iid_ed, prox_50c_iid_ed, med_50c_iid_ed, Yogi_50c_iid_ed, Q_50c_iid_ed]
strat_names = ['fedAvg', 'fedProx', 'fedMedian', 'fedYogi', 'QFedAvg']

for i, strat in enumerate(strats):
    plt.plot(strat, label = strat_names[i])

plt.legend()
plt.grid()
plt.title("MNIST 50c, IID, ed")
# Out:
# Text(0.5, 1.0, 'MNIST 50c, IID, ed')

# %%
## nIID, ed
strats = [favg_50c_niid_ed, prox_50c_niid_ed, med_50c_niid_ed, Yogi_50c_niid_ed, Q_50c_niid_ed]
strat_names = ['fedAvg', 'fedProx', 'fedMedian', 'fedYogi', 'QFedAvg']

for i, strat in enumerate(strats):
    plt.plot(strat, label = strat_names[i])

plt.legend()
plt.grid()
plt.title("MNIST 50c, nIID, ed")
# Out:
# Text(0.5, 1.0, 'MNIST 50c, nIID, ed')

# %%
## IID, ned
strats = [favg_50c_iid_ned, prox_50c_iid_ned, med_50c_iid_ned, Yogi_50c_iid_ned, Q_50c_iid_ned]
strat_names = ['fedAvg', 'fedProx', 'fedMedian', 'fedYogi', 'QFedAvg']

for i, strat in enumerate(strats):
    plt.plot(strat, label = strat_names[i])

plt.legend()
plt.grid()
plt.title("MNIST 50c, IID, ned")
# Out:
# Text(0.5, 1.0, 'MNIST 50c, IID, ned')

# %%
## nIID, ned
strats = [favg_50c_niid_ned, prox_50c_niid_ned, med_50c_niid_ned, Yogi_50c_niid_ned, Q_50c_niid_ned]
strat_names = ['fedAvg', 'fedProx', 'fedMedian', 'fedYogi', 'QFedAvg']

for i, strat in enumerate(strats):
    plt.plot(strat, label = strat_names[i])

plt.legend()
plt.grid()
plt.title("MNIST 50c, nIID, ned")
# Out:
# Text(0.5, 1.0, 'MNIST 50c, nIID, ned')
